# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df= pd.read_csv('/kaggle/input/supermarket-sales/supermarket_sales - Sheet1.csv')

# %%
df.head()

# %%
df.shape

# %%
df.info()

# %%
df.isnull().sum()

# %%
df.duplicated().sum()

# %%
df.describe()

# %%
df['Rating'].value_counts()

# %% [markdown]
# Type Casting

# %%
df.columns

# %%
df.rename({'cogs':'Cogs','gross margin percentage':'Gross margin percentage','gross income':'Gross income'},axis=1,inplace=True)

# %%
df.head()

# %%
df.info()

# %% [markdown]
# # Converting the data type

# %%
df['Unit price']=df['Unit price'].astype('int64')
df['Tax 5%']=df['Tax 5%'].astype('int')
df['Total']=df['Total'].astype('int')
df['Tax 5%']=df['Tax 5%'].astype('int')
df['Gross income']=df['Gross income'].astype('int')

# %%
df.info()

# %%
df.isnull().sum()

# %%
df.head()

# %% [markdown]
# # EDA

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.barplot(x='Gender',y='Gross income',data=df)

# %% [markdown]
# The female customers in the supermarket are more than the male customers.

# %%
df['Payment'].nunique()

# %%
df['Payment'].unique()

# %%
#lets visualize the payment vs gross income

sns.barplot(x='Payment',y='Gross income',data=df)

# %% [markdown]
# The preferred payment methods among customers, with cash and credit card payments being highly favored. However, the dataset includes a small number of outlier customers, among whom the most preferred payment mode is credit card.

# %%
#product v/s quantity
plt.figure(figsize=(12,5))
sns.barplot(x='Product line',y='Quantity',data=df)

# %%
sns.barplot(x='Customer type',y='Gross income',data=df)

# %% [markdown]
# The customers with membership purchased more than the normal customers.

# %%
sns.barplot(x='City',y='Gross income',data=df)

# %% [markdown]
# customers in the city Naypyitaw purchase more than other city customers

# %%
#income vs branch
sns.barplot(x='Branch',y='Gross income',data=df)

# %% [markdown]
# The customers from the C branch produce much more income than other branches.
